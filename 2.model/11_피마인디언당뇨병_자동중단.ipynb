# %% [markdown]
# # 피마인디언 당뇨병

# %%
from google.colab import files
import numpy as np
import tensorflow as tf

# %%
# 실행할 때마다 같은 결과를 출력하기 위한 seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ### 데이터 전처리

# %%
file_uploaded = files.upload()
# Out:
#      <input type="file" id="files-abd2472f-0cbc-471f-b29e-81781c645c8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abd2472f-0cbc-471f-b29e-81781c645c8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pima-indians-diabetes.csv to pima-indians-diabetes.csv

# %%
filename = list(file_uploaded.keys())[0]

# %%
dataset = np.loadtxt(filename,delimiter=',')
dataset
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %% [markdown]
# ####정규화

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_norm = scale.fit_transform(dataset[:, :-1])
Y = dataset[:, -1]
X_norm.shape, Y.shape
# Out:
# ((768, 8), (768,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(
    X_norm, Y,stratify=Y,random_state = seed
)
X_train.shape,X_test.shape
# Out:
# ((576, 8), (192, 8))

# %% [markdown]
# ### 모델 설계

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input

# %%
model = Sequential([
    Dense(12, input_shape=(8,), activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# ### 모델 환경설정

# %%
model.compile(
                loss='binary_crossentropy', 
                optimizer='adam', 
                metrics=['accuracy']
            )

# %% [markdown]
# ### 모델 저장 관련 환경 설정

# %%
import os
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# !ls
# Out:
# model  pima-indians-diabetes.csv  sample_data

# %%
# 모델 저장 조건
modelpath = MODEL_DIR + "best{epoch:03d}-{val_loss:.4f}.hdf5"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(patience=30)

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(X_train,y_train, validation_split=0.2, epochs=200, batch_size=50, callbacks=[checkpointer,early_stopping])
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 25ms/step - loss: 0.6544 - accuracy: 0.6107 - val_loss: 0.6141 - val_accuracy: 0.6379
#
# Epoch 00001: val_loss improved from inf to 0.61408, saving model to ./model/best001-0.6141.hdf5
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6274 - accuracy: 0.6698 - val_loss: 0.5967 - val_accuracy: 0.6466
#
# Epoch 00002: val_loss improved from 0.61408 to 0.59672, saving model to ./model/best002-0.5967.hdf5
# Epoch 3/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6065 - accuracy: 0.6923 - val_loss: 0.5823 - val_accuracy: 0.6552
#
# Epoch 00003: val_loss improved from 0.59672 to 0.58231, saving model to ./model/best003-0.5823.hdf5
# Epoch 4/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5886 - accuracy: 0.7010 - val_loss: 0.5718 - val_accuracy: 0.6638
#
# Epoch 00004: val_loss improved from 0.58231 to 0.57177, saving model to ./model/best004-0.5718.hdf5
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5858 - accuracy: 0.6975 - val_loss: 0.5635 - val_accuracy: 0.6466
#
# Epoch 00005: val_loss improved from 0.57177 to 0.56351, saving model to ./model/best005-0.5635.hdf5
# Epoch 6/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5648 - accuracy: 0.7288 - val_loss: 0.5562 - val_accuracy: 0.6466
#
# Epoch 00006: val_loss improved from 0.56351 to 0.55622, saving model to ./model/best006-0.5562.hdf5
# Epoch 7/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5505 - accuracy: 0.7117 - val_loss: 0.5510 - val_accuracy: 0.6552
#
# Epoch 00007: val_loss improved from 0.55622 to 0.55095, saving model to ./model/best007-0.5510.hdf5
# Epoch 8/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5410 - accuracy: 0.7391 - val_loss: 0.5469 - val_accuracy: 0.6466
#
# Epoch 00008: val_loss improved from 0.55095 to 0.54692, saving model to ./model/best008-0.5469.hdf5
# Epoch 9/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5458 - accuracy: 0.7263 - val_loss: 0.5433 - val_accuracy: 0.6724
#
# Epoch 00009: val_loss improved from 0.54692 to 0.54331, saving model to ./model/best009-0.5433.hdf5
# Epoch 10/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5385 - accuracy: 0.7288 - val_loss: 0.5395 - val_accuracy: 0.6724
#
# Epoch 00010: val_loss improved from 0.54331 to 0.53953, saving model to ./model/best010-0.5395.hdf5
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5240 - accuracy: 0.7552 - val_loss: 0.5376 - val_accuracy: 0.6724
#
# Epoch 00011: val_loss improved from 0.53953 to 0.53757, saving model to ./model/best011-0.5376.hdf5
# Epoch 12/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5155 - accuracy: 0.7519 - val_loss: 0.5358 - val_accuracy: 0.6724
#
# Epoch 00012: val_loss improved from 0.53757 to 0.53585, saving model to ./model/best012-0.5358.hdf5
# Epoch 13/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5016 - accuracy: 0.7647 - val_loss: 0.5339 - val_accuracy: 0.6810
#
# Epoch 00013: val_loss improved from 0.53585 to 0.53393, saving model to ./model/best013-0.5339.hdf5
# Epoch 14/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5237 - accuracy: 0.7444 - val_loss: 0.5318 - val_accuracy: 0.6983
#
# Epoch 00014: val_loss improved from 0.53393 to 0.53177, saving model to ./model/best014-0.5318.hdf5
# Epoch 15/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4849 - accuracy: 0.7613 - val_loss: 0.5309 - val_accuracy: 0.6983
#
# Epoch 00015: val_loss improved from 0.53177 to 0.53086, saving model to ./model/best015-0.5309.hdf5
# Epoch 16/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.7752 - val_loss: 0.5294 - val_accuracy: 0.6983
#
# Epoch 00016: val_loss improved from 0.53086 to 0.52944, saving model to ./model/best016-0.5294.hdf5
# Epoch 17/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5036 - accuracy: 0.7519 - val_loss: 0.5280 - val_accuracy: 0.6983
#
# Epoch 00017: val_loss improved from 0.52944 to 0.52801, saving model to ./model/best017-0.5280.hdf5
# Epoch 18/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.4987 - accuracy: 0.7722 - val_loss: 0.5261 - val_accuracy: 0.7155
#
# Epoch 00018: val_loss improved from 0.52801 to 0.52611, saving model to ./model/best018-0.5261.hdf5
# Epoch 19/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4909 - accuracy: 0.7769 - val_loss: 0.5263 - val_accuracy: 0.6983
#
# Epoch 00019: val_loss did not improve from 0.52611
# Epoch 20/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4811 - accuracy: 0.7768 - val_loss: 0.5263 - val_accuracy: 0.6897
#
# Epoch 00020: val_loss did not improve from 0.52611
# Epoch 21/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5015 - accuracy: 0.7509 - val_loss: 0.5264 - val_accuracy: 0.6897
#
# Epoch 00021: val_loss did not improve from 0.52611
# Epoch 22/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4388 - accuracy: 0.8073 - val_loss: 0.5276 - val_accuracy: 0.6897
#
# Epoch 00022: val_loss did not improve from 0.52611
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5018 - accuracy: 0.7417 - val_loss: 0.5283 - val_accuracy: 0.6983
#
# Epoch 00023: val_loss did not improve from 0.52611
# Epoch 24/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4886 - accuracy: 0.7567 - val_loss: 0.5291 - val_accuracy: 0.6983
#
# Epoch 00024: val_loss did not improve from 0.52611
# Epoch 25/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4593 - accuracy: 0.7662 - val_loss: 0.5309 - val_accuracy: 0.6983
#
# Epoch 00025: val_loss did not improve from 0.52611
# Epoch 26/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4851 - accuracy: 0.7945 - val_loss: 0.5310 - val_accuracy: 0.7069
#
# Epoch 00026: val_loss did not improve from 0.52611
# Epoch 27/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5001 - accuracy: 0.7778 - val_loss: 0.5309 - val_accuracy: 0.7069
#
# Epoch 00027: val_loss did not improve from 0.52611
# Epoch 28/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 0.8134 - val_loss: 0.5329 - val_accuracy: 0.7069
#
# Epoch 00028: val_loss did not improve from 0.52611
# Epoch 29/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4776 - accuracy: 0.7723 - val_loss: 0.5339 - val_accuracy: 0.7069
#
# Epoch 00029: val_loss did not improve from 0.52611
# Epoch 30/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4691 - accuracy: 0.7895 - val_loss: 0.5346 - val_accuracy: 0.7069
#
# Epoch 00030: val_loss did not improve from 0.52611
# Epoch 31/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4486 - accuracy: 0.8037 - val_loss: 0.5341 - val_accuracy: 0.6983
#
# Epoch 00031: val_loss did not improve from 0.52611
# Epoch 32/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4553 - accuracy: 0.7901 - val_loss: 0.5332 - val_accuracy: 0.6983
#
# Epoch 00032: val_loss did not improve from 0.52611
# Epoch 33/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4329 - accuracy: 0.8007 - val_loss: 0.5327 - val_accuracy: 0.6983
#
# Epoch 00033: val_loss did not improve from 0.52611
# Epoch 34/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4659 - accuracy: 0.7808 - val_loss: 0.5328 - val_accuracy: 0.6983
#
# Epoch 00034: val_loss did not improve from 0.52611
# Epoch 35/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4386 - accuracy: 0.8021 - val_loss: 0.5345 - val_accuracy: 0.6983
#
# Epoch 00035: val_loss did not improve from 0.52611
# Epoch 36/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4822 - accuracy: 0.7715 - val_loss: 0.5368 - val_accuracy: 0.7155
#
# Epoch 00036: val_loss did not improve from 0.52611
# Epoch 37/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4785 - accuracy: 0.7809 - val_loss: 0.5375 - val_accuracy: 0.7155
#
# Epoch 00037: val_loss did not improve from 0.52611
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4485 - accuracy: 0.8014 - val_loss: 0.5399 - val_accuracy: 0.7069
#
# Epoch 00038: val_loss did not improve from 0.52611
# Epoch 39/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4437 - accuracy: 0.8042 - val_loss: 0.5407 - val_accuracy: 0.7069
#
# Epoch 00039: val_loss did not improve from 0.52611
# Epoch 40/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4501 - accuracy: 0.8052 - val_loss: 0.5436 - val_accuracy: 0.7069
#
# Epoch 00040: val_loss did not improve from 0.52611
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4421 - accuracy: 0.7938 - val_loss: 0.5438 - val_accuracy: 0.6983
#
# Epoch 00041: val_loss did not improve from 0.52611
# Epoch 42/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4203 - accuracy: 0.8063 - val_loss: 0.5451 - val_accuracy: 0.6983
#
# Epoch 00042: val_loss did not improve from 0.52611
# Epoch 43/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4511 - accuracy: 0.7962 - val_loss: 0.5463 - val_accuracy: 0.6983
#
# Epoch 00043: val_loss did not improve from 0.52611
# Epoch 44/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4423 - accuracy: 0.7995 - val_loss: 0.5471 - val_accuracy: 0.6897
#
# Epoch 00044: val_loss did not improve from 0.52611
# Epoch 45/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4469 - accuracy: 0.7924 - val_loss: 0.5477 - val_accuracy: 0.6983
#
# Epoch 00045: val_loss did not improve from 0.52611
# Epoch 46/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4202 - accuracy: 0.8034 - val_loss: 0.5486 - val_accuracy: 0.7155
#
# Epoch 00046: val_loss did not improve from 0.52611
# Epoch 47/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4548 - accuracy: 0.7851 - val_loss: 0.5493 - val_accuracy: 0.7155
#
# Epoch 00047: val_loss did not improve from 0.52611
# Epoch 48/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4515 - accuracy: 0.7838 - val_loss: 0.5497 - val_accuracy: 0.7155
#
# Epoch 00048: val_loss did not improve from 0.52611

# %%
from tensorflow.keras.models import load_model
best_model = load_model('./model/best018-0.5261.hdf5')
acc = best_model.evaluate(X_test, y_test, verbose=2)
print(f"Accuracy: {acc[1]:.4f}")
# Out:
# 6/6 - 0s - loss: 0.4848 - accuracy: 0.7865
# Accuracy: 0.7865

# %% [markdown]
# ### 테스트

# %%
index = 10
test_data = X_test[index,:].reshape(1,-1)
test_data
# Out:
# array([[-0.54791859,  2.38188392,  0.04624525,  4.92186584, -0.69289057,
#          0.34362394,  0.31144581,  2.44704844]])

# %%
label = y_test[index]
int(label)
# Out:
# 1

# %%
pred = model.predict(test_data)
pred
# Out:
# array([[0.82371205]], dtype=float32)

# %%
int(pred[0][0] > 0.5)
# Out:
# 1
