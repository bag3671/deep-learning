# %% [markdown]
# # 순환 신경망 - 나비야

# %%
# 사용할 패키지 불러오기
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback

# %%
# 랜덤시드 고정시키기
np.random.seed(5)

# %%
code2idx = {'c4':0, 'd4':1, 'e4':2, 'f4':3, 'g4':4, 'a4':5, 'b4':6,
            'c8':7, 'd8':8, 'e8':9, 'f8':10, 'g8':11, 'a8':12, 'b8':13}
idx2code = {0:'c4', 1:'d4', 2:'e4', 3:'f4', 4:'g4', 5:'a4', 6:'b4',
            7:'c8', 8:'d8', 9:'e8', 10:'f8', 11:'g8', 12:'a8', 13:'b8'}

# %%
import numpy as np

def seq2dataset(seq, window_size):
    dataset = []
    for i in range(len(seq)-window_size):
        subset = seq[i:(i+window_size+1)]
        dataset.append([code2idx[item] for item in subset])
    return np.array(dataset)

# %%
seq = ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4',
       'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4',
       'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4',
       'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']
dataset = seq2dataset(seq, window_size = 4)

dataset.shape
# Out:
# (50, 5)

# %%
dataset[:5]
# Out:
# array([[11,  9,  2, 10,  8],
#        [ 9,  2, 10,  8,  1],
#        [ 2, 10,  8,  1,  7],
#        [10,  8,  1,  7,  8],
#        [ 8,  1,  7,  8,  9]])

# %%
# 데이터셋 생성하기
dataset = seq2dataset(seq, window_size = 4)
dataset.shape
# Out:
# (50, 5)

# %%
# 입력(X)과 출력(Y) 변수로 분리하기
x_train = dataset[:,0:4]
y_train = dataset[:,4]

MAX_IDX_VALUE = 13

# %%
# 입력값 정규화 시키기
x_train = x_train / float(MAX_IDX_VALUE)
x_train.shape
# Out:
# (50, 4)

# %%
x_train = np.reshape(x_train, (50, 4, 1))

# %%
# 라벨값에 대한 one-hot 인코딩 수행
y_train = to_categorical(y_train)
one_hot_vec_size = y_train.shape[1]
one_hot_vec_size
# Out:
# 12

# %%
# 손실 이력 클래스 정의
class LossHistory(Callback):
    def init(self):
        self.losses = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

# %%
# 모델 구성하기
model = Sequential()
model.add(LSTM(128, batch_input_shape = (1, 4, 1), stateful=True))
model.add(Dense(one_hot_vec_size, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 128)                  66560
# _________________________________________________________________
# dense_1 (Dense)              (1, 12)                   1548
# =================================================================
# Total params: 68,108
# Trainable params: 68,108
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 학습과정 설정하기
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 모델 학습시키기
num_epochs = 201
history = LossHistory()
history.init()

for epoch_idx in range(num_epochs):
    if epoch_idx % 50 == 0:
        print("======================= " + str(epoch_idx) + " =======================")
    model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2, shuffle=False,
              callbacks=[history]) # 50 is X.shape[0]
    model.reset_states()
# Out:
# ======================= 0 =======================
# 50/50 - 1s - loss: 2.4206 - accuracy: 0.3000
# 50/50 - 0s - loss: 2.0030 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9629 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9460 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9365 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9294 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9237 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9189 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9145 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9104 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9062 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9016 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8972 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8927 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.8865 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8884 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.8856 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9657 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.9056 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8982 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8924 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8815 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8713 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8536 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8131 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.8423 - accuracy: 0.3800
# 50/50 - 0s - loss: 1.8371 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.8554 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8091 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8551 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8225 - accuracy: 0.3800
# 50/50 - 0s - loss: 1.7982 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.7736 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.7900 - accuracy: 0.3000
# 50/50 - 0s - loss: 1.8473 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.7725 - accuracy: 0.3800
# 50/50 - 0s - loss: 1.7715 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.8187 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.7388 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.7519 - accuracy: 0.3800
# 50/50 - 0s - loss: 1.7463 - accuracy: 0.4200
# 50/50 - 0s - loss: 2.2519 - accuracy: 0.3200
# 50/50 - 0s - loss: 1.7665 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.7382 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.7354 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.7002 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.6668 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.7201 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.6603 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.6645 - accuracy: 0.4000
# ======================= 50 =======================
# 50/50 - 0s - loss: 1.6159 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.6723 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.6811 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.7653 - accuracy: 0.3600
# 50/50 - 0s - loss: 1.7273 - accuracy: 0.3400
# 50/50 - 0s - loss: 1.6166 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.5754 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.5457 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.5544 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.6267 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.5628 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.5759 - accuracy: 0.4400
# 50/50 - 0s - loss: 1.4974 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.4775 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.5164 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.4596 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.5603 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.4587 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.4522 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.4708 - accuracy: 0.4400
# 50/50 - 0s - loss: 1.4330 - accuracy: 0.4800
# 50/50 - 0s - loss: 1.3774 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.3320 - accuracy: 0.5200
# 50/50 - 0s - loss: 1.2960 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.4422 - accuracy: 0.4400
# 50/50 - 0s - loss: 1.4239 - accuracy: 0.4400
# 50/50 - 0s - loss: 1.3246 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.2442 - accuracy: 0.4800
# 50/50 - 0s - loss: 1.2367 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.4028 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.2017 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.2426 - accuracy: 0.5400
# 50/50 - 0s - loss: 1.0944 - accuracy: 0.5600
# 50/50 - 0s - loss: 1.2454 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.2552 - accuracy: 0.5200
# 50/50 - 0s - loss: 1.1922 - accuracy: 0.5400
# 50/50 - 0s - loss: 1.5522 - accuracy: 0.4800
# 50/50 - 0s - loss: 1.2575 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.0864 - accuracy: 0.5800
# 50/50 - 0s - loss: 1.1309 - accuracy: 0.6400
# 50/50 - 0s - loss: 1.4705 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.5244 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.6862 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.4948 - accuracy: 0.4200
# 50/50 - 0s - loss: 1.3520 - accuracy: 0.4400
# 50/50 - 0s - loss: 1.2222 - accuracy: 0.5800
# 50/50 - 0s - loss: 1.3143 - accuracy: 0.5200
# 50/50 - 0s - loss: 1.5182 - accuracy: 0.5400
# 50/50 - 0s - loss: 1.2172 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.4829 - accuracy: 0.4800
# ======================= 100 =======================
# 50/50 - 0s - loss: 1.5020 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.3794 - accuracy: 0.4600
# 50/50 - 0s - loss: 1.2866 - accuracy: 0.5200
# 50/50 - 0s - loss: 1.1870 - accuracy: 0.5000
# 50/50 - 0s - loss: 1.1087 - accuracy: 0.5800
# 50/50 - 0s - loss: 1.1409 - accuracy: 0.5600
# 50/50 - 0s - loss: 1.1585 - accuracy: 0.6000
# 50/50 - 0s - loss: 1.0516 - accuracy: 0.6200
# 50/50 - 0s - loss: 1.0659 - accuracy: 0.6000
# 50/50 - 0s - loss: 1.2149 - accuracy: 0.5800
# 50/50 - 0s - loss: 0.8991 - accuracy: 0.7200
# 50/50 - 0s - loss: 0.9148 - accuracy: 0.6400
# 50/50 - 0s - loss: 1.1164 - accuracy: 0.5800
# 50/50 - 0s - loss: 1.1760 - accuracy: 0.5600
# 50/50 - 0s - loss: 0.9830 - accuracy: 0.5800
# 50/50 - 0s - loss: 1.0199 - accuracy: 0.6200
# 50/50 - 0s - loss: 1.3995 - accuracy: 0.4600
# 50/50 - 0s - loss: 0.9094 - accuracy: 0.6200
# 50/50 - 0s - loss: 0.9157 - accuracy: 0.6800
# 50/50 - 0s - loss: 1.0685 - accuracy: 0.5800
# 50/50 - 0s - loss: 0.9662 - accuracy: 0.6200
# 50/50 - 0s - loss: 1.0452 - accuracy: 0.6400
# 50/50 - 0s - loss: 0.9744 - accuracy: 0.6400
# 50/50 - 0s - loss: 0.8941 - accuracy: 0.6600
# 50/50 - 0s - loss: 0.6619 - accuracy: 0.8000
# 50/50 - 0s - loss: 0.5710 - accuracy: 0.8200
# 50/50 - 0s - loss: 0.9698 - accuracy: 0.6000
# 50/50 - 0s - loss: 1.4760 - accuracy: 0.4000
# 50/50 - 0s - loss: 0.9142 - accuracy: 0.6400
# 50/50 - 0s - loss: 0.7902 - accuracy: 0.7000
# 50/50 - 0s - loss: 0.9376 - accuracy: 0.6800
# 50/50 - 0s - loss: 0.9087 - accuracy: 0.5800
# 50/50 - 0s - loss: 0.6999 - accuracy: 0.7400
# 50/50 - 0s - loss: 1.0609 - accuracy: 0.5800
# 50/50 - 0s - loss: 0.6487 - accuracy: 0.7400
# 50/50 - 0s - loss: 0.6378 - accuracy: 0.7200
# 50/50 - 0s - loss: 0.4570 - accuracy: 0.9200
# 50/50 - 0s - loss: 0.3338 - accuracy: 0.9600
# 50/50 - 0s - loss: 0.4501 - accuracy: 0.8400
# 50/50 - 0s - loss: 0.9939 - accuracy: 0.5400
# 50/50 - 0s - loss: 0.9756 - accuracy: 0.6800
# 50/50 - 0s - loss: 1.0948 - accuracy: 0.6400
# 50/50 - 0s - loss: 1.0121 - accuracy: 0.5200
# 50/50 - 0s - loss: 0.7149 - accuracy: 0.7600
# 50/50 - 0s - loss: 0.4618 - accuracy: 0.7800
# 50/50 - 0s - loss: 0.3752 - accuracy: 0.8800
# 50/50 - 0s - loss: 0.2873 - accuracy: 0.9400
# 50/50 - 0s - loss: 0.2317 - accuracy: 0.9600
# 50/50 - 0s - loss: 0.2160 - accuracy: 0.9800
# 50/50 - 0s - loss: 0.1974 - accuracy: 0.9800
# ======================= 150 =======================
# 50/50 - 0s - loss: 1.7605 - accuracy: 0.5400
# 50/50 - 0s - loss: 1.5410 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.3028 - accuracy: 0.5800
# 50/50 - 0s - loss: 1.0807 - accuracy: 0.5600
# 50/50 - 0s - loss: 1.0512 - accuracy: 0.6000
# 50/50 - 0s - loss: 0.9997 - accuracy: 0.5600
# 50/50 - 0s - loss: 0.9352 - accuracy: 0.6000
# 50/50 - 0s - loss: 0.8207 - accuracy: 0.6800
# 50/50 - 0s - loss: 0.6992 - accuracy: 0.6800
# 50/50 - 0s - loss: 0.5815 - accuracy: 0.7800
# 50/50 - 0s - loss: 0.6040 - accuracy: 0.7800
# 50/50 - 0s - loss: 0.6020 - accuracy: 0.7800
# 50/50 - 0s - loss: 0.7111 - accuracy: 0.7200
# 50/50 - 0s - loss: 1.1912 - accuracy: 0.5400
# 50/50 - 0s - loss: 0.7442 - accuracy: 0.7600
# 50/50 - 0s - loss: 0.7734 - accuracy: 0.6600
# 50/50 - 0s - loss: 0.4782 - accuracy: 0.9000
# 50/50 - 0s - loss: 0.3257 - accuracy: 0.9200
# 50/50 - 0s - loss: 0.2194 - accuracy: 0.9600
# 50/50 - 0s - loss: 0.1573 - accuracy: 0.9800
# 50/50 - 0s - loss: 0.1666 - accuracy: 0.9800
# 50/50 - 0s - loss: 1.2810 - accuracy: 0.4600
# 50/50 - 0s - loss: 0.4628 - accuracy: 0.7800
# 50/50 - 0s - loss: 0.7747 - accuracy: 0.7200
# 50/50 - 0s - loss: 0.5581 - accuracy: 0.8000
# 50/50 - 0s - loss: 2.1385 - accuracy: 0.4000
# 50/50 - 0s - loss: 1.4144 - accuracy: 0.4400
# 50/50 - 0s - loss: 1.0001 - accuracy: 0.6000
# 50/50 - 0s - loss: 0.9403 - accuracy: 0.6600
# 50/50 - 0s - loss: 1.0299 - accuracy: 0.5400
# 50/50 - 0s - loss: 0.6082 - accuracy: 0.7600
# 50/50 - 0s - loss: 0.4659 - accuracy: 0.8600
# 50/50 - 0s - loss: 0.2976 - accuracy: 0.9800
# 50/50 - 0s - loss: 0.2163 - accuracy: 1.0000
# 50/50 - 0s - loss: 0.1528 - accuracy: 1.0000
# 50/50 - 0s - loss: 0.1195 - accuracy: 1.0000
# 50/50 - 0s - loss: 0.1155 - accuracy: 1.0000
# 50/50 - 0s - loss: 0.1013 - accuracy: 1.0000
# 50/50 - 0s - loss: 0.1382 - accuracy: 0.9800
# 50/50 - 0s - loss: 0.5451 - accuracy: 0.8400
# 50/50 - 0s - loss: 0.6688 - accuracy: 0.7000
# 50/50 - 0s - loss: 1.3513 - accuracy: 0.6200
# 50/50 - 0s - loss: 1.2101 - accuracy: 0.5200
# 50/50 - 0s - loss: 0.6759 - accuracy: 0.7200
# 50/50 - 0s - loss: 0.7569 - accuracy: 0.6800
# 50/50 - 0s - loss: 0.4226 - accuracy: 0.8600
# 50/50 - 0s - loss: 0.2922 - accuracy: 0.9000
# 50/50 - 0s - loss: 0.3921 - accuracy: 0.8800
# 50/50 - 0s - loss: 0.2932 - accuracy: 0.9000
# 50/50 - 0s - loss: 0.1753 - accuracy: 0.9800
# ======================= 200 =======================
# 50/50 - 0s - loss: 0.1442 - accuracy: 0.9800

# %%
# 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.losses)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
# 모델 평가하기
scores = model.evaluate(x_train, y_train, batch_size=1)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
model.reset_states()
# Out:
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0847 - accuracy: 1.0000
# accuracy: 100.00%

# %%
# 모델 사용하기
pred_count = 50   # 최대 예측 개수 정의

# %%
# 한 스텝 예측
seq_out = ['g8', 'e8', 'e4', 'f8']
pred_out = model.predict(x_train, batch_size=1)

for i in range(pred_count):
    idx = np.argmax(pred_out[i]) # one-hot 인코딩을 인덱스 값으로 변환
    seq_out.append(idx2code[idx]) # seq_out는 최종 악보이므로 인덱스 값을 코드로 변환하여 저장
model.reset_states()

print("one step prediction : ", seq_out)
# Out:
# one step prediction :  ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4', 'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4', 'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4', 'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']

# %%
# 곡 전체 예측
seq_in = ['g8', 'e8', 'e4', 'f8']
seq_out = seq_in
seq_in = [code2idx[it] / float(MAX_IDX_VALUE) for it in seq_in] # 코드를 인덱스값으로 변환

for i in range(pred_count):
    sample_in = np.array(seq_in)
    sample_in = np.reshape(sample_in, (1, 4, 1)) # 샘플 수, 타입스텝 수, 속성 수
    pred_out = model.predict(sample_in)
    idx = np.argmax(pred_out)
    seq_out.append(idx2code[idx])
    seq_in.append(idx / float(MAX_IDX_VALUE))
    seq_in.pop(0)
model.reset_states()
    
print("full song prediction : ", seq_out)
# Out:
# full song prediction :  ['g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'd8', 'e8', 'f8', 'g8', 'g8', 'g4', 'g8', 'e8', 'e8', 'e8', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4', 'd8', 'd8', 'd8', 'd8', 'd8', 'e8', 'f4', 'e8', 'e8', 'e8', 'e8', 'e8', 'f8', 'g4', 'g8', 'e8', 'e4', 'f8', 'd8', 'd4', 'c8', 'e8', 'g8', 'g8', 'e8', 'e8', 'e4']
