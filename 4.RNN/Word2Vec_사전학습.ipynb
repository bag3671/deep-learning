# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2021-02-24 02:42:04--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.94.205
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.94.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  68.5MB/s    in 25s
#
# 2021-02-24 02:42:30 (62.4 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %% [markdown]
# 압축파일을 풀지 않고 모델에 압축파일 그래도 넣어도 돌아감 대신 시간이 좀 걸림

# %%
# !gzip -d GoogleNews-vectors-negative300.bin.gz

# %%
# !ls -l

# %%
import gensim

# 구글의 사전 훈련된 Word2Vec 모델을 로드합니다.
# model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)  
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
print(model.vectors.shape) # 모델의 크기 확인
# Out:
# (3000000, 300)

# %%
print (model.similarity('girl', 'princess')) # 두 단어의 유사도 계산하기
print (model.similarity('girl', 'prince'))
# Out:
# 0.52582425
# 0.34684256

# %%
print(model['book']) # 단어 'book'의 벡터 출력
# Out:
# [ 0.11279297 -0.02612305 -0.04492188  0.06982422  0.140625    0.03039551
#  -0.04370117  0.24511719  0.08740234 -0.05053711  0.23144531 -0.07470703
#   0.21875     0.03466797 -0.14550781  0.05761719  0.00671387 -0.00701904
#   0.13183594 -0.25390625  0.14355469 -0.140625   -0.03564453 -0.21289062
#  -0.24804688  0.04980469 -0.09082031  0.14453125  0.05712891 -0.10400391
#  -0.19628906 -0.20507812 -0.27539062  0.03063965  0.20117188  0.17382812
#   0.09130859 -0.10107422  0.22851562 -0.04077148  0.02709961 -0.00106049
#   0.02709961  0.34179688 -0.13183594 -0.078125    0.02197266 -0.18847656
#  -0.17480469 -0.05566406 -0.20898438  0.04858398 -0.07617188 -0.15625
#  -0.05419922  0.01672363 -0.02722168 -0.11132812 -0.03588867 -0.18359375
#   0.28710938  0.01757812  0.02185059 -0.05664062 -0.01251221  0.01708984
#  -0.21777344 -0.06787109  0.04711914 -0.00668335  0.08544922 -0.02209473
#   0.31835938  0.01794434 -0.02246094 -0.03051758 -0.09570312  0.24414062
# ...

# %%
model.most_similar("book")
# Out:
# [('tome', 0.7485830783843994),
#  ('books', 0.7379178404808044),
#  ('memoir', 0.7302927374839783),
#  ('paperback_edition', 0.6868364810943604),
#  ('autobiography', 0.6741527915000916),
#  ('memoirs', 0.6505153179168701),
#  ('Book', 0.6479282379150391),
#  ('paperback', 0.6471226811408997),
#  ('novels', 0.6341458559036255),
#  ('hardback', 0.6283079385757446)]

# %%
model.most_similar(positive=['King','woman'],negative=['man'],topn=3)
# Out:
# [('Queen', 0.5515626072883606),
#  ('Oprah_BFF_Gayle', 0.47597548365592957),
#  ('Geoffrey_Rush_Exit', 0.46460166573524475)]

# %% [markdown]
# ## 한글

# %%
# !pip install gdown

# %%
# !gdown --id 0B0ZXk88koS2KbDhXdWg1Q2RydlU --output ko.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=0B0ZXk88koS2KbDhXdWg1Q2RydlU
# To: /content/ko.zip
# 80.6MB [00:00, 82.8MB/s]

# %%
# !unzip -qq ko.zip -d .

# %%
import gensim
k_model = gensim.models.Word2Vec.load('ko.bin')
k_model.wv.vectors.shape
# Out:
# (30185, 200)

# %%
k_model.wv.most_similar("강아지")
# Out:
# [('고양이', 0.7290452718734741),
#  ('거위', 0.7185635566711426),
#  ('토끼', 0.7056223154067993),
#  ('멧돼지', 0.6950401067733765),
#  ('엄마', 0.6934334635734558),
#  ('난쟁이', 0.6806551218032837),
#  ('한마리', 0.6770296096801758),
#  ('아가씨', 0.6750352382659912),
#  ('아빠', 0.6729634404182434),
#  ('목걸이', 0.6512460708618164)]

# %%
# 한국 - 서울 + 도쿄
k_model.wv.most_similar(positive=['한국', '뉴욕'], negative=['서울'], topn=3)
# Out:
# [('미국', 0.644524872303009),
#  ('캐나다', 0.5397665500640869),
#  ('영국', 0.5312756299972534)]
